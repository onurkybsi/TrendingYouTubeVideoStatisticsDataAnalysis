# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sn

# %%
dataWarehouse = pd.read_csv("arrangedDataset.csv")[["video_id","trending_date","title","channel_title","category","category_id","publish_time","tags","views","likes","dislikes","comment_count","thumbnail_link","comments_disabled","ratings_disabled","video_error_or_removed","description","country_abb"]]

# %%
# Finding disable state

# commentsDisabledTrue = 0
# commentsDisabledFalse = 0
# ratingsDisabledTrue = 0
# ratingsDisabledFalse = 0

# for x in range(0,375942):
#     if(dataWarehouse["comments_disabled"][x] == True):
#         commentsDisabledTrue += 1
#     else:
#         commentsDisabledFalse +=1
#     if(dataWarehouse["ratings_disabled"][x] == True):
#         ratingsDisabledTrue += 1
#     else:
#         ratingsDisabledFalse += 1

# disabledState = [commentsDisabledTrue,commentsDisabledFalse,ratingsDisabledTrue,ratingsDisabledFalse]

# print(disabledState)
# Out:
# [8463, 367479, 7308, 368634]

# %%
# RelationBetweenCommentsDisabledState

plt.pie([8463,367479], labels=["Disabled","Enabled"], wedgeprops={'edgecolor':'black'}, explode=[0,0.2] , shadow=True, autopct="%1.1f%%")
plt.title("Relation between comments disabled state")
plt.show()

# %%
# RelationBetweenRatingsDisabledState

plt.pie([7308,368634], labels=["Disabled","Enabled"], wedgeprops={'edgecolor':'black'}, explode=[0,0.2] , shadow=True,autopct="%1.1f%%")
plt.title("Relation between ratings disabled state")
plt.show()
